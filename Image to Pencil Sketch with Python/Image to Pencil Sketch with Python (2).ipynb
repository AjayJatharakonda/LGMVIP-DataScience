# %% [markdown]
# # LEVEL-BEGINNERS LEVEL TASK

# %% [markdown]
# # TASK NAME- IMAGE TO PENCIL SKETCH WITH PYTHON

# %%
import cv2
import numpy as np
from PIL import Image as im

# %% [markdown]
# READING OF IMAGE

# %%
image=cv2.imread('pic.png')

# %%
image
# Out:
# array([[[248, 248, 248],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247]],
#
#        [[247, 247, 247],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [247, 247, 247]],
#
#        [[247, 247, 247],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [247, 247, 247]],
#
#        ...,
#
#        [[247, 247, 247],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [247, 247, 247]],
#
#        [[247, 247, 247],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [247, 247, 247]],
#
#        [[248, 248, 248],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [247, 247, 247]]], dtype=uint8)

# %% [markdown]
# CONVERTING TO GRAY IMAGE AND DISPLAYING

# %%
grey_filter=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
grey_filter.shape
# Out:
# (662, 820)

# %%
grey=im.fromarray(grey_filter)

# %%
grey
# Out:
# <PIL.Image.Image image mode=L size=820x662 at 0x2376E75F910>

# %% [markdown]
# CONVERTING TO INVERT AND DISPLAYING

# %%
invert=cv2.bitwise_not(grey_filter)

# %%
invert.shape
# Out:
# (662, 820)

# %%
inv=im.fromarray(invert)

# %%
inv
# Out:
# <PIL.Image.Image image mode=L size=820x662 at 0x2376E85D2B0>

# %% [markdown]
# CONVERTING TO BLUR AND DISPLAYING THE IMAGE

# %%
blur=cv2.GaussianBlur(invert,(21,21),0)

# %%
blur.shape
# Out:
# (662, 820)

# %%
bl=im.fromarray(blur)

# %%
bl
# Out:
# <PIL.Image.Image image mode=L size=820x662 at 0x2376E85DC70>

# %% [markdown]
# CONVERTING TO INVERTEDBLUR AND DISPLAYING

# %%
invertedblur=cv2.bitwise_not(blur)

# %%
invertedblur.shape
# Out:
# (662, 820)

# %%
inve=im.fromarray(invertedblur)

# %%
inve
# Out:
# <PIL.Image.Image image mode=L size=820x662 at 0x2376E869040>

# %% [markdown]
# #CONVERTING TO  PENCIL SKETCH FORM AND DISPLAYING

# %%
sketch_filter=cv2.divide(grey_filter,invertedblur,scale=256.0)

# %%
cv2.imwrite('output.png',sketch_filter)
# Out:
# True

# %%
sketch_filter.shape
# Out:
# (662, 820)

# %%
data=im.fromarray(sketch_filter)

# %% [markdown]
# # FINAL OUTPUT

# %%
data
# Out:
# <PIL.Image.Image image mode=L size=820x662 at 0x2376E869970>
